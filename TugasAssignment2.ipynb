# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Numpy merupakan library python digunakan komputasi matriks
# Matplotlib meruapakan library python untuk presentasi data berupa grafik atau plot

# %%
dataset = pd.read_csv('Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['Adware' 48.0]
#  ['Backdoor' 11.0]
#  ['File Infector' 5.0]
#  ['No_Category' nan]
#  ['PUA' 8.0]
#  ['Ransomware' 8.0]
#  ['Riskware' 21.0]
#  ['Scareware' 3.0]
#  ['Trojan' 45.0]
#  ['Trojan-Banker' 11.0]
#  ['Trojan-Dropper' 9.0]
#  ['Trojan-SMS' 11.0]
#  ['Trojan-Spy' 11.0]
#  ['Zero-day' nan]]

# %%
print(y)
# Out:
# ['47,210' '1,538' '669' '2,296' '2,051' '6,202' '97,349' '1,556' '13,559'
#  '887' '2,302' '3,125' '3,540' '13,340']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(x[:, 1:3])
x[:, 1:3] = imputer.transform(x[:, 1:3])

# %%
print (x)
# Out:
# [['Adware' 48.0]
#  ['Backdoor' 11.0]
#  ['File Infector' 5.0]
#  ['No_Category' nan]
#  ['PUA' 8.0]
#  ['Ransomware' 8.0]
#  ['Riskware' 21.0]
#  ['Scareware' 3.0]
#  ['Trojan' 45.0]
#  ['Trojan-Banker' 11.0]
#  ['Trojan-Dropper' 9.0]
#  ['Trojan-SMS' 11.0]
#  ['Trojan-Spy' 11.0]
#  ['Zero-day' nan]]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[0])], remainder='passthrough')
x = np.array(ct.fit_transform(x))

# %%
print (x)
# Out:
#   (0, 0)	1.0
#   (0, 14)	48.0
#   (1, 1)	1.0
#   (1, 14)	11.0
#   (2, 2)	1.0
#   (2, 14)	5.0
#   (3, 3)	1.0
#   (3, 14)	15.916666666666666
#   (4, 4)	1.0
#   (4, 14)	8.0
#   (5, 5)	1.0
#   (5, 14)	8.0
#   (6, 6)	1.0
#   (6, 14)	21.0
#   (7, 7)	1.0
#   (7, 14)	3.0
#   (8, 8)	1.0
#   (8, 14)	45.0
#   (9, 9)	1.0
#   (9, 14)	11.0
#   (10, 10)	1.0
#   (10, 14)	9.0
#   (11, 11)	1.0
#   (11, 14)	11.0
#   (12, 12)	1.0
#   (12, 14)	11.0
#   (13, 13)	1.0
#   (13, 14)	15.916666666666666

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print (y)
# Out:
# [ 9  0 11  5  4 10 13  1  3 12  6  7  8  2]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-57cef014fa3b> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2557         raise ValueError("At least one array required as input")
#    2558
# -> 2559     arrays = indexable(*arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     392     """
#     393
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     392     """
#     393
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     333     if hasattr(x, "shape") and x.shape is not None:
#     334         if len(x.shape) == 0:
# --> 335             raise TypeError(
#     336                 "Singleton array %r cannot be considered a valid collection." % x
#     337             )
#
# TypeError: Singleton array array(<14x15 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>, dtype=object) cannot be considered a valid collection.

# %%
print(x_train)
# Out:
# [['Trojan-Banker' 11.0]
#  ['Trojan-Dropper' 9.0]
#  ['No Category' nan]
#  ['File Infector' 5.0]
#  ['PUA' 8.0]
#  ['Zero-day' nan]
#  ['Riskware' 21.0]
#  ['Backdoor' 11.0]
#  ['Trojan-Spy' 11.0]
#  ['Adware' 48.0]]

# %%
print(x_test)
# Out:
# [['Trojan' 45.0]
#  ['Scareware' 3.0]
#  ['Ransomware' 8.0]
#  ['Trojan-SMS' 11.0]]

# %%
print(y_train)
# Out:
# ['887' '2,302' '2,296' '669' '2,051' '13,340' '97,349' '1,538' '3,540'
#  '47,210']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train[:, 1:] = sc.fit_transform(x_train[:, 1:])
x_test[:, 1:] = sc.fit_transform(x_test[:, 1:])

# %%
print(x_train)
# Out:
# [['Trojan-Banker' -0.3456429176891559]
#  ['Trojan-Dropper' -0.4992619922176696]
#  ['No Category' nan]
#  ['File Infector' -0.806500141274697]
#  ['PUA' -0.5760715294819264]
#  ['Zero-day' nan]
#  ['Riskware' 0.4224524549534127]
#  ['Backdoor' -0.3456429176891559]
#  ['Trojan-Spy' -0.3456429176891559]
#  ['Adware' 2.496309961088348]]

# %%
print(x_test)
# Out:
# [['Trojan' 1.7060612790164629]
#  ['Scareware' -0.8303838083708447]
#  ['Ransomware' -0.5284260598723557]
#  ['Trojan-SMS' -0.3472514107732623]]
