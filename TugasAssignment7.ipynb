# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv('Data.csv')
dataset.keys()
# Out:
# Index(['Number of families', 'Number of samples'], dtype='object')

# %%
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#    Number of families  Number of samples
# 0                  48              47000
# 1                  11               1538
# 2                   5                669
# 3                   0               2296
# 4                   8               2051

# %%
X = np.asarray(dataset)
print(X)
# Out:
# [[   48 47000]
#  [   11  1538]
#  [    5   669]
#  [    0  2296]
#  [    8  2051]
#  [    8  6202]
#  [   21 97349]
#  [    3  1556]
#  [   45 13559]
#  [   11   887]
#  [    9  2302]
#  [   11  3125]
#  [   11  3540]
#  [    0 13340]]

# %%
plt.scatter(X[:,0], X[:,1], label='True Position')
plt.xlabel("Number Of Families")
plt.ylabel("Number Of Samples")
plt.title("Grafik Total Copies")
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.30769231e+01 7.54346154e+03]
#  [2.10000000e+01 9.73490000e+04]]

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.xlabel("Number Of Families")
plt.ylabel("Number Of Samples")
plt.title("Grafik Total Copies")
plt.show()

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel("Number Of Families")
plt.ylabel("Number Of Samples")
plt.title("Grafik Total Copies")
plt.show()
